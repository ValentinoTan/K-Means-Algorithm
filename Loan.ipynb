# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load the dataset
df_loan = pd.read_csv("loan.csv")

# Selecting relevant columns
df_kmeans = df_loan[["Income", "Loan Amount"]]

# Standardizing the data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_kmeans)

# Applying K-Means with k=4
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
df_loan["Cluster"] = kmeans.fit_predict(df_scaled)

# Visualizing the clusters
plt.figure(figsize=(8, 6))
scatter = plt.scatter(df_loan["Income"], df_loan["Loan Amount"], c=df_loan["Cluster"], cmap="viridis", edgecolors="k")
plt.xlabel("Income")
plt.ylabel("Loan Amount")
plt.title("K-Means Clustering on Loan Data (k=4)")
plt.colorbar(scatter, label="Cluster")
plt.grid(True)
plt.show()
